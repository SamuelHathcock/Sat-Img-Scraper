# %% [markdown]
# ## Todo:
# - Function to count lightning strikes within a timeframe

# %%
import satSpider as spider
import m as m

# %% [markdown]
# # Making the information the spider will use to find the image in the websites database

# %%
productlist = ['eumetsat_ash', 'geocolor']

#2021 03 12 2330 17
year = '2021'
month = '03'
day = '12'
hour = '2330'
second = '17'

date = '/' + year + month + day
satellite = '/' + 'goes-16---full_disk'
product = '/' + productlist[1]
time = '/' + year + month + day + hour + second
zoomlevel = '/' + '04'
row_column = '/' + '003_002.png'

# %% [markdown]
# # Using the spider to get the desired image

# %%
img_name = 'oceans.jpg'

spider.request_image(
    img_name, 
    date,
    satellite,
    product,
    time,
    zoomlevel,
    row_column
    )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-3c1b80f4a98d> in <module>
#       2
#       3 spider = spider
# ----> 4 spider.request_image(
#       5     img_name,
#       6     date,
#
# AttributeError: module 'satSpider' has no attribute 'request_image'

# %% [markdown]
# # Displaying the image

# %%
Image(img_name)

# %% [markdown]
# **In order to perform some kind of analysis, such as determining the level of SO2 in the atmosphere, we will need to use the other the sattelites "jma_so2" product.**

# %%
spider.request_image(
    img_name, 
    date,
    satellite,
    'jma_so2',
    time,
    zoomlevel,
    row_column
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e9623fa38fc1> in <module>
# ----> 1 spider.request_image(
#       2     img_name,
#       3     date,
#       4     satellite,
#       5     'jma_so2',
#
# NameError: name 'spider' is not defined

# %%
import module1

productlist = ['eumetsat_ash', 'geocolor']

day = '/' + '20210226'
satellite = '/' + 'goes-16---full_disk'
product = '/' + productlist[1]
time = day + '054019'
zoomlevel = '/' + '03'
row_column = '/' + '001_002.png'

module1.request_image('selected_image2.jpg', day, satellite, product, time, zoomlevel, row_column)

Image('selected_image2.jpg')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-14-86a4b77a13f5> in <module>
#      10 row_column = '/' + '001_002.png'
#      11
# ---> 12 module1.request_image('selected_image2.jpg', day, satellite, product, time, zoomlevel, row_column)
#      13
#      14 Image('selected_image2.jpg')
#
# ~/Desktop/Educational/WebScraping/Satellite_img_Scraper/sattelite-img-scrapper/module1.py in request_image(name, day, satellite, product, time, zoomlevel, row_column)
#       9
#      10     resourceLink = baseURL + src
# ---> 11     urllib.request.urlretrieve(resourceLink, name)
#      12
#
# ~/Desktop/PythonFiles/Anaconda/lib/python3.8/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     245     url_type, path = _splittype(url)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
#     248         headers = fp.info()
#     249
#
# ...
